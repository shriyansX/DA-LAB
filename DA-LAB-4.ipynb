# %%
t = (10, 20, 30, 40, 50)
print("First element:", t[0])
print("Last element:", t[-1])
print("Slice (1 to 3):", t[1:4])
# Out:
# First element: 10
# Last element: 50
# Slice (1 to 3): (20, 30, 40)

# %%
t = (5, 10, 15, 20)
n = int(input("Enter number: "))
if n in t:
    print("Number exists in tuple")
else:
    print("Number does not exist")
# Out:
# Number does not exist

# %%
t1 = (1, 2, 3)
t2 = (4, 5)
t3 = t1 + t2
print("Concatenated tuple:", t3)
# Out:
# Concatenated tuple: (1, 2, 3, 4, 5)

# %%
t = (1, 2, 3, 2, 4, 2)
x = int(input("Enter value: "))
print("Count:", t.count(x))
print("First index:", t.index(x))
# Out:
# Count: 1
# First index: 0

# %%
lst = list(map(int, input("Enter list elements: ").split()))
t = tuple(lst)
print("Tuple:", t)
# Out:
# Tuple: (5,)

# %%
t = (4, 1, 3, 2)
sorted_t = tuple(sorted(t))
print("Original tuple:", t)
print("Sorted tuple:", sorted_t)
# Out:
# Original tuple: (4, 1, 3, 2)
# Sorted tuple: (1, 2, 3, 4)

# %%
t = (10, 5, 20, 3)
print("Maximum:", max(t))
print("Minimum:", min(t))
# Out:
# Maximum: 20
# Minimum: 3

# %%
a = {1, 2, 3}
b = {3, 4, 5}

print("Union:", a | b)
print("Intersection:", a & b)
print("Difference:", a - b)
print("Symmetric Difference:", a ^ b)
# Out:
# Union: {1, 2, 3, 4, 5}
# Intersection: {3}
# Difference: {1, 2}
# Symmetric Difference: {1, 2, 4, 5}

# %%
s = {1, 2, 3}
s.add(4)
s.remove(2)
print("Updated set:", s)
# Out:
# Updated set: {1, 3, 4}

# %%
a = {1, 2}
b = {1, 2, 3}

print("a is subset of b:", a.issubset(b))
print("b is superset of a:", b.issuperset(a))
# Out:
# a is subset of b: True
# b is superset of a: True

# %%
lst = [1, 2, 2, 3, 3, 4]
unique = list(set(lst))
print("Without duplicates:", unique)
# Out:
# Without duplicates: [1, 2, 3, 4]

# %%
s = input("Enter string: ")
char_set = set(s)
print("Character set:", char_set)
# Out:
# Character set: {'N', 'A', 'Y', 'S', 'R', 'I', 'H'}

# %%
sentence = input("Enter sentence: ")
words = set(sentence.split())
print("Unique words:", words)
# Out:
# Unique words: {'THIS', 'HELLO', 'IS', 'SHRIYANS'}

# %%
s = input("Enter string: ")
print("Reversed:", s[::-1])
# Out:
# Reversed: SNAYIRHS

# %%
s = input("Enter sentence: ")
vowels = "aeiouAEIOU"
count = 0
for ch in s:
    if ch in vowels:
        count += 1
print("Vowel count:", count)
# Out:
# Vowel count: 6

# %%
s = input("Enter string: ")
if s == s[::-1]:
    print("Palindrome")
else:
    print("Not a palindrome")
# Out:
# Palindrome

# %%
s = input("Enter string: ")
freq = {}
for ch in s:
    freq[ch] = freq.get(ch, 0) + 1
print(freq)
# Out:
# {'S': 2, 'H': 1, 'R': 1, 'I': 1, 'Y': 1, 'A': 1, 'N': 1}

# %%
sentence = input("Enter sentence: ")
print("Word count:", len(sentence.split()))
# Out:
# Word count: 4

# %%
s = input("Enter string: ")
print("Without spaces:", s.replace(" ", ""))
# Out:
# Without spaces: SHRIYANS

# %%
s = input("Enter string: ")
old = input("Old substring: ")
new = input("New substring: ")
print("Result:", s.replace(old, new))
# Out:
# Result: Shriyans

# %%
sentence = input("Enter sentence: ")
words = sentence.split()
print("Longest word:", max(words, key=len))
# Out:
# Longest word: shriyans

# %%
student = {"name": "Rahul", "age": 20, "marks": 85}
print(student["name"])
print(student["age"])
print(student["marks"])
# Out:
# Rahul
# 20
# 85

# %%
student = {"name": "Rahul", "age": 20}
student["marks"] = 90
student["age"] = 21
print(student)
# Out:
# {'name': 'Rahul', 'age': 21, 'marks': 90}

# %%
student = {"name": "Rahul", "age": 20}
student.pop("age")
print(student)
# Out:
# {'name': 'Rahul'}

# %%
student = {"name": "Rahul", "age": 20}
key = input("Enter key: ")
if key in student:
    print("Key exists")
else:
    print("Key does not exist")
# Out:
# Key does not exist

# %%
student = {"name": "Rahul", "age": 20}
for k, v in student.items():
    print(k, ":", v)
# Out:
# name : Rahul
# age : 20

# %%
para = input("Enter paragraph: ")
freq = {}
for word in para.split():
    freq[word] = freq.get(word, 0) + 1
print(freq)
# Out:
# {'hello': 1, 'here': 1}

# %%
keys = ["a", "b", "c"]
values = [1, 2, 3]
d = dict(zip(keys, values))
print(d)
# Out:
# {'a': 1, 'b': 2, 'c': 3}

# %%
d = {i: i*i for i in range(1, 11)}
print(d)
# Out:
# {1: 1, 2: 4, 3: 9, 4: 16, 5: 25, 6: 36, 7: 49, 8: 64, 9: 81, 10: 100}

# %%
lst = [1, 2, 2, 3, 3, 3]
freq = {}
for i in lst:
    freq[i] = freq.get(i, 0) + 1
print(freq)
# Out:
# {1: 1, 2: 2, 3: 3}

# %%
t = ("banana", "apple", "cherry")
sorted_t = tuple(sorted(t))
print("Sorted tuple:", sorted_t)
# Out:
# Sorted tuple: ('apple', 'banana', 'cherry')
